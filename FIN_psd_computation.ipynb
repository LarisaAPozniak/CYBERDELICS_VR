# %%
import mne
import os
import os.path as op
import numpy as np
import pandas as  pd
import matplotlib.pyplot as plt
import re
import glob
from mne.preprocessing import annotate_muscle_zscore

# %%
subjects = ['AS32', 'CB55', 'DE21', 'DF23', 'EE89', 'FK11', 'FK24', 'fx48',
       'GF87', 'GG88', 'GS21', 'HG11', 'JK67', 'JU77', 'KI09', 'KL72',
       'KO33', 'LL90', 'MN99', 'MO45', 'NO21', 'OO11', 'OP01', 'PO67',
       'PP00', 'RD56', 'RO88', 'RT12', 'TR90', 'TY65', 'YT50']

# %%
files  = os.listdir('D:/CYBERDELICS/CLEANED EPOCHS')
print(files)

# %%
#list_epochs = []
for file in files:
    epoch = mne.read_epochs(f"D:/CYBERDELICS/CLEANED EPOCHS/{file}", preload=True)
    epoch = epoch.apply_baseline(baseline=(None, 0))
    epoch = epoch.interpolate_bads(reset_bads=True, mode='accurate')
    #epoch.info = epoch[0].info
    #list_epochs.append(epoch)
    epoch.compute_psd().to_data_frame().to_csv(f'...path/psd_df/{file[:-8]}.csv')
